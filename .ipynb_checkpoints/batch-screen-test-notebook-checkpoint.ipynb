# %%
import json
import logging
import os
import pandas as pd
import requests
from tqdm import tqdm
from dotenv import load_dotenv

# %%
# Loading environmental variables
# Be sure to update your .env file to include your API Key
load_dotenv()
# Out:
# True

# %%
##### ENTER YOUR API KEY
API_KEY = os.getenv("API_KEY")

# %%
input_csv = "sample_addresses.csv"
df = pd.read_csv(input_csv)

# %%
df.head()
# Out:
#    user_id                                     address
# 0        1  0x6acdfba02d390b97ac2b2d42a63e85293bcc160e
# 1        2  0x7F19720A857F834887FC9A7bC0a0fBe7Fc7f8102
# 2        3  0x92193107FB10B3B372AB21cC90b5a4DBd67861d9
# 3        4  0xe1e8C9fa8F0cB41CcF9b92061b696EC247Fcc449
# 4        5  0xC5Ca16CD564eA101bBF2Dba1346499289F142B07

# %%
# Define header JSON to be used in each API call.
headers = {"token": API_KEY, "Content-Type": "application/json"}

# %%
# ITERATE
# Iterate over each row of the CSV file and call the Address Screening API.
# https://docs.chainalysis.com/api/address-screening/#register-an-address
responses = []
print("Registering and evaluating addresses...")
for index, row in tqdm(df.iterrows(), total=df.shape[0]):
    address = row["address"]

    # BUILD REGISTRATION API CALL
    REGISTER_URL = "https://api.chainalysis.com/api/risk/v2/entities"

    # Load parsed inputs into a json object to be used in the payload of the API request
    newPayload = json.dumps({"address": address})

    # Call registration API. Do nothing with it.
    r = requests.request("POST", REGISTER_URL, headers=headers, data=newPayload)

    # BUILD FETCH API CALL
    FETCH_URL = f"https://api.chainalysis.com/api/risk/v2/entities/{address}"

    response = requests.request("GET", FETCH_URL, headers=headers)

    # Write output to `responses` list
    responses.append(json.loads(response.text))

    logging.info("Called address: %s", address)

logging.info("All API calls finished.")
# Out:
# Registering and evaluating addresses...
# 100%|██████████| 11/11 [00:17<00:00,  1.61s/it]

# %%
# In order to correctly flatten the JSON, we need to alter the JSON for those responses where `addressIdentifications` is an empty list. We simply add an empty dict.
# more info: https://stackoverflow.com/questions/63813378/how-to-json-normalize-a-column-in-pandas-with-empty-lists-without-losing-record/63876897#63876897
# Flattening
for i, d in enumerate(responses):
    if not d["addressIdentifications"]:
        responses[i]["addressIdentifications"] = [{}]

# Dropping type None, which represent errored API responses.
data = []
for i in responses:
    if i is not None:
        data.append(i)

# %%
exposures = pd.json_normalize(
    data,
    meta=[
        "address",
        ["exposures"],
        ["cluster", "name"],
        ["cluster", "category"],
        "risk",
    ],
    record_path="exposures",
    errors="ignore",
)

exposures.head()
# Out:
#                           category         value  \
# 0                              atm  1.109293e+08
# 1             child abuse material  2.259392e+07
# 2                   darknet market  1.090872e+09
# 3  decentralized exchange contract  4.697410e+11
# 4                         exchange  7.379873e+12
#
#                                       address  \
# 0  0x6acdfba02d390b97ac2b2d42a63e85293bcc160e
# 1  0x6acdfba02d390b97ac2b2d42a63e85293bcc160e
# 2  0x6acdfba02d390b97ac2b2d42a63e85293bcc160e
# 3  0x6acdfba02d390b97ac2b2d42a63e85293bcc160e
# 4  0x6acdfba02d390b97ac2b2d42a63e85293bcc160e
#
#                                            exposures  \
# 0  [{'category': 'atm', 'value': 110929305.0}, {'...
# 1  [{'category': 'atm', 'value': 110929305.0}, {'...
# 2  [{'category': 'atm', 'value': 110929305.0}, {'...
# 3  [{'category': 'atm', 'value': 110929305.0}, {'...
# 4  [{'category': 'atm', 'value': 110929305.0}, {'...
#
#                      cluster.name cluster.category    risk
# 0  OFAC SDN Chatex.com 2021-11-08        sanctions  Severe
# 1  OFAC SDN Chatex.com 2021-11-08        sanctions  Severe
# 2  OFAC SDN Chatex.com 2021-11-08        sanctions  Severe
# 3  OFAC SDN Chatex.com 2021-11-08        sanctions  Severe
# 4  OFAC SDN Chatex.com 2021-11-08        sanctions  Severe

# %%
triggers = pd.json_normalize(
    data, meta=["address", ["triggers"]], record_path="triggers"
)

triggers.head()
# Out:
#                  category  percentage  \
# 0    child abuse material    0.000176
# 1          darknet market    0.008504
# 2              fraud shop    0.039281
# 3                gambling    0.206272
# 4  high risk jurisdiction    0.000040
#
#                                    message ruleTriggered.risk  \
# 0    > 0% exposure to child abuse material             Severe
# 1          > 0% exposure to darknet market             Medium
# 2              > 0% exposure to fraud shop             Medium
# 3                > 0% exposure to gambling             Medium
# 4  > 0% exposure to high risk jurisdiction             Severe
#
#    ruleTriggered.minThreshold  ruleTriggered.maxThreshold  \
# 0                         0.0                         1.0
# 1                         0.0                         0.1
# 2                         0.0                         0.1
# 3                         0.0                         0.1
# 4                         0.0                         1.0
#
#                                       address  \
# 0  0x6acdfba02d390b97ac2b2d42a63e85293bcc160e
# 1  0x6acdfba02d390b97ac2b2d42a63e85293bcc160e
# 2  0x6acdfba02d390b97ac2b2d42a63e85293bcc160e
# 3  0x6acdfba02d390b97ac2b2d42a63e85293bcc160e
# 4  0x6acdfba02d390b97ac2b2d42a63e85293bcc160e
#
#                                             triggers
# 0  [{'category': 'child abuse material', 'percent...
# 1  [{'category': 'child abuse material', 'percent...
# 2  [{'category': 'child abuse material', 'percent...
# 3  [{'category': 'child abuse material', 'percent...
# 4  [{'category': 'child abuse material', 'percent...

# %%
addressIdentifications = pd.json_normalize(
    data,
    meta=["address", ["addressIdentifications"]],
    record_path="addressIdentifications",
    record_prefix="addressId_",
)

addressIdentifications.head()
# Out:
#                                       addressId_name addressId_category  \
# 0  SANCTIONS: OFAC SDN Chatex.com 2021-11-08 6acd...          sanctions
# 1  SANCTIONS: OFAC SDN Secondeye Solution 2021-04...          sanctions
# 2  STOLEN FUNDS: Contact Chainalysis 0x9219 92193...       stolen funds
# 3                                                NaN                NaN
# 4                                                NaN                NaN
#
#                                addressId_description  \
# 0  Sanctions: OFAC SDN Chatex.com 2021-11-08 0x6a...
# 1  Pakistan-based Secondeye Solution (SES), also ...
# 2  Please contact your Chainalysis representative...
# 3                                                NaN
# 4                                                NaN
#
#                                       address  \
# 0  0x6acdfba02d390b97ac2b2d42a63e85293bcc160e
# 1  0x7F19720A857F834887FC9A7bC0a0fBe7Fc7f8102
# 2  0x92193107FB10B3B372AB21cC90b5a4DBd67861d9
# 3  0xe1e8C9fa8F0cB41CcF9b92061b696EC247Fcc449
# 4  0xC5Ca16CD564eA101bBF2Dba1346499289F142B07
#
#                               addressIdentifications
# 0  {'name': 'SANCTIONS: OFAC SDN Chatex.com 2021-...
# 1  {'name': 'SANCTIONS: OFAC SDN Secondeye Soluti...
# 2  {'name': 'STOLEN FUNDS: Contact Chainalysis 0x...
# 3                                                 {}
# 4                                                 {}

# %%
### Merging the three flattened dataframes to one
df1 = pd.merge(left=exposures, right=triggers, on=["address", "category"], how="outer")
details = pd.merge(left=df1, right=addressIdentifications, on="address", how="outer")

details.head()
# Out:
#                           category         value  \
# 0                              atm  1.109293e+08
# 1             child abuse material  2.259392e+07
# 2                   darknet market  1.090872e+09
# 3  decentralized exchange contract  4.697410e+11
# 4                         exchange  7.379873e+12
#
#                                       address  \
# 0  0x6acdfba02d390b97ac2b2d42a63e85293bcc160e
# 1  0x6acdfba02d390b97ac2b2d42a63e85293bcc160e
# 2  0x6acdfba02d390b97ac2b2d42a63e85293bcc160e
# 3  0x6acdfba02d390b97ac2b2d42a63e85293bcc160e
# 4  0x6acdfba02d390b97ac2b2d42a63e85293bcc160e
#
#                                            exposures  \
# 0  [{'category': 'atm', 'value': 110929305.0}, {'...
# 1  [{'category': 'atm', 'value': 110929305.0}, {'...
# 2  [{'category': 'atm', 'value': 110929305.0}, {'...
# 3  [{'category': 'atm', 'value': 110929305.0}, {'...
# 4  [{'category': 'atm', 'value': 110929305.0}, {'...
#
#                      cluster.name cluster.category    risk  percentage  \
# 0  OFAC SDN Chatex.com 2021-11-08        sanctions  Severe         NaN
# 1  OFAC SDN Chatex.com 2021-11-08        sanctions  Severe    0.000176
# 2  OFAC SDN Chatex.com 2021-11-08        sanctions  Severe    0.008504
# 3  OFAC SDN Chatex.com 2021-11-08        sanctions  Severe         NaN
# 4  OFAC SDN Chatex.com 2021-11-08        sanctions  Severe         NaN
#
#                                  message ruleTriggered.risk  \
# 0                                    NaN                NaN
# 1  > 0% exposure to child abuse material             Severe
# 2        > 0% exposure to darknet market             Medium
# 3                                    NaN                NaN
# 4                                    NaN                NaN
#
#    ruleTriggered.minThreshold  ruleTriggered.maxThreshold  \
# 0                         NaN                         NaN
# 1                         0.0                         1.0
# 2                         0.0                         0.1
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#                                             triggers  \
# 0                                                NaN
# 1  [{'category': 'child abuse material', 'percent...
# 2  [{'category': 'child abuse material', 'percent...
# 3                                                NaN
# 4                                                NaN
#
#                                       addressId_name addressId_category  \
# 0  SANCTIONS: OFAC SDN Chatex.com 2021-11-08 6acd...          sanctions
# 1  SANCTIONS: OFAC SDN Chatex.com 2021-11-08 6acd...          sanctions
# 2  SANCTIONS: OFAC SDN Chatex.com 2021-11-08 6acd...          sanctions
# 3  SANCTIONS: OFAC SDN Chatex.com 2021-11-08 6acd...          sanctions
# 4  SANCTIONS: OFAC SDN Chatex.com 2021-11-08 6acd...          sanctions
#
#                                addressId_description  \
# 0  Sanctions: OFAC SDN Chatex.com 2021-11-08 0x6a...
# 1  Sanctions: OFAC SDN Chatex.com 2021-11-08 0x6a...
# 2  Sanctions: OFAC SDN Chatex.com 2021-11-08 0x6a...
# 3  Sanctions: OFAC SDN Chatex.com 2021-11-08 0x6a...
# 4  Sanctions: OFAC SDN Chatex.com 2021-11-08 0x6a...
#
#                               addressIdentifications
# 0  {'name': 'SANCTIONS: OFAC SDN Chatex.com 2021-...
# 1  {'name': 'SANCTIONS: OFAC SDN Chatex.com 2021-...
# 2  {'name': 'SANCTIONS: OFAC SDN Chatex.com 2021-...
# 3  {'name': 'SANCTIONS: OFAC SDN Chatex.com 2021-...
# 4  {'name': 'SANCTIONS: OFAC SDN Chatex.com 2021-...

# %%
# Formatting Details csv
cols = [
    "address",
    "risk",
    "cluster.name",
    "cluster.category",
    "ruleTriggered.risk",
    "category",
    "value",
    "percentage",
    "message",
    "addressId_name",
    "addressId_category",
    "addressId_description",
]

details = details[cols]

newCols = [
    "address",
    "risk",
    "cluster.name",
    "cluster.category",
    "exposure.rule.riskLevel",
    "exposure.category",
    "exposure.value",
    "exposure.percentage",
    "exposure.rule.message",
    "addressId.name",
    "addressId.category",
    "addressId.description",
]

details.columns = newCols

# %%
exposures = pd.pivot_table(exposures, index="address", columns=["category"])
triggers = pd.pivot_table(triggers, index="address", columns=["category"])

exposures.head()
# Out:
#                                                    value                       \
# category                                             atm child abuse material
# address
# 0x0002AdC5dc5b503026C2847629F7ec9044Bb5435  6.840919e+13         4.231184e+10
# 0x003ca8A7e40bEDB2b95358717A4deFe67ede554b  4.711789e+10         3.573498e+06
# 0x6acdfba02d390b97ac2b2d42a63e85293bcc160e  1.109293e+08         2.259392e+07
# 0x7F19720A857F834887FC9A7bC0a0fBe7Fc7f8102           NaN                  NaN
# 0x92193107FB10B3B372AB21cC90b5a4DBd67861d9           NaN                  NaN
#
#                                                            \
# category                                   darknet market
# address
# 0x0002AdC5dc5b503026C2847629F7ec9044Bb5435   2.251968e+13
# 0x003ca8A7e40bEDB2b95358717A4deFe67ede554b   2.898917e+09
# 0x6acdfba02d390b97ac2b2d42a63e85293bcc160e   1.090872e+09
# 0x7F19720A857F834887FC9A7bC0a0fBe7Fc7f8102   1.814192e+07
# 0x92193107FB10B3B372AB21cC90b5a4DBd67861d9            NaN
#
#                                                                             \
# category                                   decentralized exchange contract
# address
# 0x0002AdC5dc5b503026C2847629F7ec9044Bb5435                    6.354707e+13
# 0x003ca8A7e40bEDB2b95358717A4deFe67ede554b                    5.743564e+13
# 0x6acdfba02d390b97ac2b2d42a63e85293bcc160e                    4.697410e+11
# 0x7F19720A857F834887FC9A7bC0a0fBe7Fc7f8102                             NaN
# 0x92193107FB10B3B372AB21cC90b5a4DBd67861d9                             NaN
#
#                                                                         \
# category                                        exchange          fees
# address
# 0x0002AdC5dc5b503026C2847629F7ec9044Bb5435  3.516716e+16  6.577002e+13
# 0x003ca8A7e40bEDB2b95358717A4deFe67ede554b  3.297158e+14  1.625771e+12
# 0x6acdfba02d390b97ac2b2d42a63e85293bcc160e  7.379873e+12  3.323819e+10
# 0x7F19720A857F834887FC9A7bC0a0fBe7Fc7f8102  9.641581e+09  5.334257e+08
# 0x92193107FB10B3B372AB21cC90b5a4DBd67861d9  1.524924e+08  4.409410e+05
#
#                                                                         \
# category                                      fraud shop      gambling
# address
# 0x0002AdC5dc5b503026C2847629F7ec9044Bb5435  5.909231e+12  3.987653e+14
# 0x003ca8A7e40bEDB2b95358717A4deFe67ede554b  1.724400e+09  2.425022e+11
# 0x6acdfba02d390b97ac2b2d42a63e85293bcc160e  5.038843e+09  2.645956e+10
# 0x7F19720A857F834887FC9A7bC0a0fBe7Fc7f8102           NaN  4.202594e+07
# 0x92193107FB10B3B372AB21cC90b5a4DBd67861d9           NaN           NaN
#
#                                                                \
# category                                   high risk exchange
# address
# 0x0002AdC5dc5b503026C2847629F7ec9044Bb5435       2.330412e+14
# 0x003ca8A7e40bEDB2b95358717A4deFe67ede554b       6.259183e+12
# 0x6acdfba02d390b97ac2b2d42a63e85293bcc160e       9.616607e+11
# 0x7F19720A857F834887FC9A7bC0a0fBe7Fc7f8102       5.135276e+09
# 0x92193107FB10B3B372AB21cC90b5a4DBd67861d9                NaN
#
#                                                                    ...  \
# category                                   high risk jurisdiction  ...
# address                                                            ...
# 0x0002AdC5dc5b503026C2847629F7ec9044Bb5435           8.283227e+11  ...
# 0x003ca8A7e40bEDB2b95358717A4deFe67ede554b           4.958837e+12  ...
# 0x6acdfba02d390b97ac2b2d42a63e85293bcc160e           5.097450e+06  ...
# 0x7F19720A857F834887FC9A7bC0a0fBe7Fc7f8102                    NaN  ...
# 0x92193107FB10B3B372AB21cC90b5a4DBd67861d9                    NaN  ...
#
#                                                                            \
# category                                   protocol privacy    ransomware
# address
# 0x0002AdC5dc5b503026C2847629F7ec9044Bb5435     6.325585e+11  1.159849e+12
# 0x003ca8A7e40bEDB2b95358717A4deFe67ede554b              NaN           NaN
# 0x6acdfba02d390b97ac2b2d42a63e85293bcc160e              NaN  2.646079e+10
# 0x7F19720A857F834887FC9A7bC0a0fBe7Fc7f8102              NaN           NaN
# 0x92193107FB10B3B372AB21cC90b5a4DBd67861d9              NaN           NaN
#
#                                                                         \
# category                                       sanctions          scam
# address
# 0x0002AdC5dc5b503026C2847629F7ec9044Bb5435  5.912499e+12  1.265402e+14
# 0x003ca8A7e40bEDB2b95358717A4deFe67ede554b  5.093725e+10  2.481968e+11
# 0x6acdfba02d390b97ac2b2d42a63e85293bcc160e  1.948103e+12  2.484115e+11
# 0x7F19720A857F834887FC9A7bC0a0fBe7Fc7f8102           NaN  3.011013e+08
# 0x92193107FB10B3B372AB21cC90b5a4DBd67861d9           NaN           NaN
#
#                                                                          \
# category                                   smart contract  stolen funds
# address
# 0x0002AdC5dc5b503026C2847629F7ec9044Bb5435   1.002214e+14  1.812039e+13
# 0x003ca8A7e40bEDB2b95358717A4deFe67ede554b   1.118105e+12  1.152011e+10
# 0x6acdfba02d390b97ac2b2d42a63e85293bcc160e   4.379690e+11  8.013131e+06
# 0x7F19720A857F834887FC9A7bC0a0fBe7Fc7f8102            NaN           NaN
# 0x92193107FB10B3B372AB21cC90b5a4DBd67861d9            NaN           NaN
#
#                                                                 \
# category                                   terrorist financing
# address
# 0x0002AdC5dc5b503026C2847629F7ec9044Bb5435        1.021237e+10
# 0x003ca8A7e40bEDB2b95358717A4deFe67ede554b        4.091484e+07
# 0x6acdfba02d390b97ac2b2d42a63e85293bcc160e                 NaN
# 0x7F19720A857F834887FC9A7bC0a0fBe7Fc7f8102                 NaN
# 0x92193107FB10B3B372AB21cC90b5a4DBd67861d9                 NaN
#
#                                                                  \
# category                                   token smart contract
# address
# 0x0002AdC5dc5b503026C2847629F7ec9044Bb5435         2.627863e+12
# 0x003ca8A7e40bEDB2b95358717A4deFe67ede554b         2.142902e+12
# 0x6acdfba02d390b97ac2b2d42a63e85293bcc160e         6.869175e+08
# 0x7F19720A857F834887FC9A7bC0a0fBe7Fc7f8102                  NaN
# 0x92193107FB10B3B372AB21cC90b5a4DBd67861d9                  NaN
#
#
# category                                   unnamed service      untraced
# address
# 0x0002AdC5dc5b503026C2847629F7ec9044Bb5435    4.096867e+15  2.454987e+13
# 0x003ca8A7e40bEDB2b95358717A4deFe67ede554b    1.618505e+13  1.305360e+09
# 0x6acdfba02d390b97ac2b2d42a63e85293bcc160e    5.622850e+11  6.509343e+07
# 0x7F19720A857F834887FC9A7bC0a0fBe7Fc7f8102    1.709459e+09           NaN
# 0x92193107FB10B3B372AB21cC90b5a4DBd67861d9             NaN           NaN
#
# [5 rows x 32 columns]

# %%
tmp_cols = ["address"]
for i in exposures.columns.tolist():
    tmp_cols.append(i[1])

exposures = pd.DataFrame(exposures.to_records())
exposures.columns = tmp_cols
exposures.fillna(0,inplace=True)
# Exposures is finished here

tmp_cols = ["address"]
for i in triggers.columns.tolist():
    tmp_cols.append(i[1])

triggers = pd.DataFrame(triggers.to_records())
triggers.columns = tmp_cols
# Triggers done

# %%
# Writing Summary table
summaryCols = ["address", "risk", "cluster.name", "cluster.category"]
s1 = details[summaryCols]
s1.drop_duplicates(subset='address',keep='first',inplace=True)
summary = pd.merge(s1,exposures,on='address',how='inner')
# Out:
# /var/folders/yd/_nr_lws54_x_rl1m73qwr99c0000gq/T/ipykernel_16995/1327219272.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s1.drop_duplicates(subset='address',keep='first',inplace=True)

# %%
exposures
# Out:
#                                        address           atm  \
# 0   0x0002AdC5dc5b503026C2847629F7ec9044Bb5435  6.840919e+13
# 1   0x003ca8A7e40bEDB2b95358717A4deFe67ede554b  4.711789e+10
# 2   0x6acdfba02d390b97ac2b2d42a63e85293bcc160e  1.109293e+08
# 3   0x7F19720A857F834887FC9A7bC0a0fBe7Fc7f8102  0.000000e+00
# 4   0x92193107FB10B3B372AB21cC90b5a4DBd67861d9  0.000000e+00
# 5   0xC5Ca16CD564eA101bBF2Dba1346499289F142B07  0.000000e+00
# 6   0xE0db7340F6eC43Af8cDE15a464e24f062167b9AB  0.000000e+00
# 7   0xe1e8C9fa8F0cB41CcF9b92061b696EC247Fcc449  2.207867e+09
# 8   0xf9911Cfb24Fe7854935Dadf94932212089968683  0.000000e+00
# 9           17edgGhhb7dp2akxj7zPFKsCTdPk46b5Z6  0.000000e+00
# 10          32PUt3ijeewVN2jjoYJqP9ReDfjhqHW3EL  6.840920e+13
#
#     child abuse material  darknet market  decentralized exchange contract  \
# 0           4.231184e+10    2.251968e+13                     6.354707e+13
# 1           3.573498e+06    2.898917e+09                     5.743564e+13
# 2           2.259392e+07    1.090872e+09                     4.697410e+11
# 3           0.000000e+00    1.814192e+07                     0.000000e+00
# 4           0.000000e+00    0.000000e+00                     0.000000e+00
# 5           0.000000e+00    0.000000e+00                     1.518121e+09
# 6           0.000000e+00    5.117910e+06                     1.433890e+09
# 7           4.681393e+08    1.340335e+11                     8.327667e+06
# 8           0.000000e+00    0.000000e+00                     0.000000e+00
# 9           0.000000e+00    0.000000e+00                     0.000000e+00
# 10          4.231184e+10    2.251968e+13                     6.354707e+13
#
#         exchange          fees    fraud shop      gambling  \
# 0   3.516716e+16  6.577002e+13  5.909231e+12  3.987653e+14
# 1   3.297158e+14  1.625771e+12  1.724400e+09  2.425022e+11
# 2   7.379873e+12  3.323819e+10  5.038843e+09  2.645956e+10
# 3   9.641581e+09  5.334257e+08  0.000000e+00  4.202594e+07
# 4   1.524924e+08  4.409410e+05  0.000000e+00  0.000000e+00
# 5   6.760072e+09  1.395998e+08  0.000000e+00  0.000000e+00
# 6   9.631649e+08  1.036450e+09  0.000000e+00  0.000000e+00
# 7   1.929037e+13  8.146525e+09  1.269018e+09  3.532520e+10
# 8   5.947287e+11  7.731941e+08  0.000000e+00  0.000000e+00
# 9   0.000000e+00  5.857430e+05  0.000000e+00  0.000000e+00
# 10  3.516732e+16  6.576995e+13  5.909231e+12  3.987680e+14
#
#     high risk exchange  ...  protocol privacy    ransomware     sanctions  \
# 0         2.330412e+14  ...      6.325585e+11  1.159849e+12  5.912499e+12
# 1         6.259183e+12  ...      0.000000e+00  0.000000e+00  5.093725e+10
# 2         9.616607e+11  ...      0.000000e+00  2.646079e+10  1.948103e+12
# 3         5.135276e+09  ...      0.000000e+00  0.000000e+00  0.000000e+00
# 4         0.000000e+00  ...      0.000000e+00  0.000000e+00  0.000000e+00
# 5         0.000000e+00  ...      0.000000e+00  0.000000e+00  0.000000e+00
# 6         0.000000e+00  ...      0.000000e+00  0.000000e+00  0.000000e+00
# 7         7.254871e+10  ...      0.000000e+00  2.194218e+08  6.508667e+10
# 8         1.791057e+09  ...      0.000000e+00  0.000000e+00  0.000000e+00
# 9         0.000000e+00  ...      0.000000e+00  2.048459e+11  0.000000e+00
# 10        2.330413e+14  ...      6.325585e+11  1.159849e+12  5.912499e+12
#
#             scam  smart contract  stolen funds  terrorist financing  \
# 0   1.265402e+14    1.002214e+14  1.812039e+13         1.021237e+10
# 1   2.481968e+11    1.118105e+12  1.152011e+10         4.091484e+07
# 2   2.484115e+11    4.379690e+11  8.013131e+06         0.000000e+00
# 3   3.011013e+08    0.000000e+00  0.000000e+00         0.000000e+00
# 4   0.000000e+00    0.000000e+00  0.000000e+00         0.000000e+00
# 5   0.000000e+00    1.423805e+09  0.000000e+00         0.000000e+00
# 6   0.000000e+00    2.850490e+10  0.000000e+00         0.000000e+00
# 7   1.444251e+08    0.000000e+00  3.478747e+10         0.000000e+00
# 8   0.000000e+00    0.000000e+00  0.000000e+00         0.000000e+00
# 9   0.000000e+00    0.000000e+00  0.000000e+00         0.000000e+00
# 10  1.265402e+14    1.002214e+14  1.812039e+13         1.021237e+10
#
#     token smart contract  unnamed service      untraced
# 0           2.627863e+12     4.096867e+15  2.454987e+13
# 1           2.142902e+12     1.618505e+13  1.305360e+09
# 2           6.869175e+08     5.622850e+11  6.509343e+07
# 3           0.000000e+00     1.709459e+09  0.000000e+00
# 4           0.000000e+00     0.000000e+00  0.000000e+00
# 5           1.474370e+09     0.000000e+00  0.000000e+00
# 6           8.249259e+09     0.000000e+00  0.000000e+00
# 7           0.000000e+00     4.701567e+11  0.000000e+00
# 8           0.000000e+00     1.495200e+09  0.000000e+00
# 9           0.000000e+00     0.000000e+00  0.000000e+00
# 10          2.627864e+12     4.096867e+15  2.636925e+13
#
# [11 rows x 33 columns]

# %%
summary
# Out:
#                                        address    risk  \
# 0   0x6acdfba02d390b97ac2b2d42a63e85293bcc160e  Severe
# 1   0x7F19720A857F834887FC9A7bC0a0fBe7Fc7f8102  Severe
# 2   0x92193107FB10B3B372AB21cC90b5a4DBd67861d9    High
# 3   0xe1e8C9fa8F0cB41CcF9b92061b696EC247Fcc449  Severe
# 4   0xC5Ca16CD564eA101bBF2Dba1346499289F142B07     Low
# 5           32PUt3ijeewVN2jjoYJqP9ReDfjhqHW3EL  Severe
# 6   0x0002AdC5dc5b503026C2847629F7ec9044Bb5435  Severe
# 7   0xf9911Cfb24Fe7854935Dadf94932212089968683     Low
# 8   0x003ca8A7e40bEDB2b95358717A4deFe67ede554b  Severe
# 9           17edgGhhb7dp2akxj7zPFKsCTdPk46b5Z6    High
# 10  0xE0db7340F6eC43Af8cDE15a464e24f062167b9AB  Medium
#
#                               cluster.name    cluster.category           atm  \
# 0           OFAC SDN Chatex.com 2021-11-08           sanctions  1.109293e+08
# 1   OFAC SDN Secondeye Solution 2021-04-15           sanctions  0.000000e+00
# 2               Contact Chainalysis 0x9219        stolen funds  0.000000e+00
# 3                           MorphToken.com  high risk exchange  2.207867e+09
# 4                                     None                None  0.000000e+00
# 5                             Coinbase.com            exchange  6.840920e+13
# 6                             Coinbase.com            exchange  6.840919e+13
# 7                                     None                None  0.000000e+00
# 8                                HotBit.io  high risk exchange  4.711789e+10
# 9    NetWalker Ransomware Affiliate 13DFuT   illicit actor-org  0.000000e+00
# 10                                    None                None  0.000000e+00
#
#     child abuse material  darknet market  decentralized exchange contract  \
# 0           2.259392e+07    1.090872e+09                     4.697410e+11
# 1           0.000000e+00    1.814192e+07                     0.000000e+00
# 2           0.000000e+00    0.000000e+00                     0.000000e+00
# 3           4.681393e+08    1.340335e+11                     8.327667e+06
# 4           0.000000e+00    0.000000e+00                     1.518121e+09
# 5           4.231184e+10    2.251968e+13                     6.354707e+13
# 6           4.231184e+10    2.251968e+13                     6.354707e+13
# 7           0.000000e+00    0.000000e+00                     0.000000e+00
# 8           3.573498e+06    2.898917e+09                     5.743564e+13
# 9           0.000000e+00    0.000000e+00                     0.000000e+00
# 10          0.000000e+00    5.117910e+06                     1.433890e+09
#
#         exchange          fees  ...  protocol privacy    ransomware  \
# 0   7.379873e+12  3.323819e+10  ...      0.000000e+00  2.646079e+10
# 1   9.641581e+09  5.334257e+08  ...      0.000000e+00  0.000000e+00
# 2   1.524924e+08  4.409410e+05  ...      0.000000e+00  0.000000e+00
# 3   1.929037e+13  8.146525e+09  ...      0.000000e+00  2.194218e+08
# 4   6.760072e+09  1.395998e+08  ...      0.000000e+00  0.000000e+00
# 5   3.516732e+16  6.576995e+13  ...      6.325585e+11  1.159849e+12
# 6   3.516716e+16  6.577002e+13  ...      6.325585e+11  1.159849e+12
# 7   5.947287e+11  7.731941e+08  ...      0.000000e+00  0.000000e+00
# 8   3.297158e+14  1.625771e+12  ...      0.000000e+00  0.000000e+00
# 9   0.000000e+00  5.857430e+05  ...      0.000000e+00  2.048459e+11
# 10  9.631649e+08  1.036450e+09  ...      0.000000e+00  0.000000e+00
#
#        sanctions          scam  smart contract  stolen funds  \
# 0   1.948103e+12  2.484115e+11    4.379690e+11  8.013131e+06
# 1   0.000000e+00  3.011013e+08    0.000000e+00  0.000000e+00
# 2   0.000000e+00  0.000000e+00    0.000000e+00  0.000000e+00
# 3   6.508667e+10  1.444251e+08    0.000000e+00  3.478747e+10
# 4   0.000000e+00  0.000000e+00    1.423805e+09  0.000000e+00
# 5   5.912499e+12  1.265402e+14    1.002214e+14  1.812039e+13
# 6   5.912499e+12  1.265402e+14    1.002214e+14  1.812039e+13
# 7   0.000000e+00  0.000000e+00    0.000000e+00  0.000000e+00
# 8   5.093725e+10  2.481968e+11    1.118105e+12  1.152011e+10
# 9   0.000000e+00  0.000000e+00    0.000000e+00  0.000000e+00
# 10  0.000000e+00  0.000000e+00    2.850490e+10  0.000000e+00
#
#     terrorist financing  token smart contract  unnamed service      untraced
# 0          0.000000e+00          6.869175e+08     5.622850e+11  6.509343e+07
# 1          0.000000e+00          0.000000e+00     1.709459e+09  0.000000e+00
# 2          0.000000e+00          0.000000e+00     0.000000e+00  0.000000e+00
# 3          0.000000e+00          0.000000e+00     4.701567e+11  0.000000e+00
# 4          0.000000e+00          1.474370e+09     0.000000e+00  0.000000e+00
# 5          1.021237e+10          2.627864e+12     4.096867e+15  2.636925e+13
# 6          1.021237e+10          2.627863e+12     4.096867e+15  2.454987e+13
# 7          0.000000e+00          0.000000e+00     1.495200e+09  0.000000e+00
# 8          4.091484e+07          2.142902e+12     1.618505e+13  1.305360e+09
# 9          0.000000e+00          0.000000e+00     0.000000e+00  0.000000e+00
# 10         0.000000e+00          8.249259e+09     0.000000e+00  0.000000e+00
#
# [11 rows x 36 columns]

# %%
exposures
# Out:
#                                        address           atm  \
# 0   0x0002AdC5dc5b503026C2847629F7ec9044Bb5435  6.840919e+13
# 1   0x003ca8A7e40bEDB2b95358717A4deFe67ede554b  4.711789e+10
# 2   0x6acdfba02d390b97ac2b2d42a63e85293bcc160e  1.109293e+08
# 3   0x7F19720A857F834887FC9A7bC0a0fBe7Fc7f8102  0.000000e+00
# 4   0x92193107FB10B3B372AB21cC90b5a4DBd67861d9  0.000000e+00
# 5   0xC5Ca16CD564eA101bBF2Dba1346499289F142B07  0.000000e+00
# 6   0xE0db7340F6eC43Af8cDE15a464e24f062167b9AB  0.000000e+00
# 7   0xe1e8C9fa8F0cB41CcF9b92061b696EC247Fcc449  2.207867e+09
# 8   0xf9911Cfb24Fe7854935Dadf94932212089968683  0.000000e+00
# 9           17edgGhhb7dp2akxj7zPFKsCTdPk46b5Z6  0.000000e+00
# 10          32PUt3ijeewVN2jjoYJqP9ReDfjhqHW3EL  6.840920e+13
#
#     child abuse material  darknet market  decentralized exchange contract  \
# 0           4.231184e+10    2.251968e+13                     6.354707e+13
# 1           3.573498e+06    2.898917e+09                     5.743564e+13
# 2           2.259392e+07    1.090872e+09                     4.697410e+11
# 3           0.000000e+00    1.814192e+07                     0.000000e+00
# 4           0.000000e+00    0.000000e+00                     0.000000e+00
# 5           0.000000e+00    0.000000e+00                     1.518121e+09
# 6           0.000000e+00    5.117910e+06                     1.433890e+09
# 7           4.681393e+08    1.340335e+11                     8.327667e+06
# 8           0.000000e+00    0.000000e+00                     0.000000e+00
# 9           0.000000e+00    0.000000e+00                     0.000000e+00
# 10          4.231184e+10    2.251968e+13                     6.354707e+13
#
#         exchange          fees    fraud shop      gambling  \
# 0   3.516716e+16  6.577002e+13  5.909231e+12  3.987653e+14
# 1   3.297158e+14  1.625771e+12  1.724400e+09  2.425022e+11
# 2   7.379873e+12  3.323819e+10  5.038843e+09  2.645956e+10
# 3   9.641581e+09  5.334257e+08  0.000000e+00  4.202594e+07
# 4   1.524924e+08  4.409410e+05  0.000000e+00  0.000000e+00
# 5   6.760072e+09  1.395998e+08  0.000000e+00  0.000000e+00
# 6   9.631649e+08  1.036450e+09  0.000000e+00  0.000000e+00
# 7   1.929037e+13  8.146525e+09  1.269018e+09  3.532520e+10
# 8   5.947287e+11  7.731941e+08  0.000000e+00  0.000000e+00
# 9   0.000000e+00  5.857430e+05  0.000000e+00  0.000000e+00
# 10  3.516732e+16  6.576995e+13  5.909231e+12  3.987680e+14
#
#     high risk exchange  ...  protocol privacy    ransomware     sanctions  \
# 0         2.330412e+14  ...      6.325585e+11  1.159849e+12  5.912499e+12
# 1         6.259183e+12  ...      0.000000e+00  0.000000e+00  5.093725e+10
# 2         9.616607e+11  ...      0.000000e+00  2.646079e+10  1.948103e+12
# 3         5.135276e+09  ...      0.000000e+00  0.000000e+00  0.000000e+00
# 4         0.000000e+00  ...      0.000000e+00  0.000000e+00  0.000000e+00
# 5         0.000000e+00  ...      0.000000e+00  0.000000e+00  0.000000e+00
# 6         0.000000e+00  ...      0.000000e+00  0.000000e+00  0.000000e+00
# 7         7.254871e+10  ...      0.000000e+00  2.194218e+08  6.508667e+10
# 8         1.791057e+09  ...      0.000000e+00  0.000000e+00  0.000000e+00
# 9         0.000000e+00  ...      0.000000e+00  2.048459e+11  0.000000e+00
# 10        2.330413e+14  ...      6.325585e+11  1.159849e+12  5.912499e+12
#
#             scam  smart contract  stolen funds  terrorist financing  \
# 0   1.265402e+14    1.002214e+14  1.812039e+13         1.021237e+10
# 1   2.481968e+11    1.118105e+12  1.152011e+10         4.091484e+07
# 2   2.484115e+11    4.379690e+11  8.013131e+06         0.000000e+00
# 3   3.011013e+08    0.000000e+00  0.000000e+00         0.000000e+00
# 4   0.000000e+00    0.000000e+00  0.000000e+00         0.000000e+00
# 5   0.000000e+00    1.423805e+09  0.000000e+00         0.000000e+00
# 6   0.000000e+00    2.850490e+10  0.000000e+00         0.000000e+00
# 7   1.444251e+08    0.000000e+00  3.478747e+10         0.000000e+00
# 8   0.000000e+00    0.000000e+00  0.000000e+00         0.000000e+00
# 9   0.000000e+00    0.000000e+00  0.000000e+00         0.000000e+00
# 10  1.265402e+14    1.002214e+14  1.812039e+13         1.021237e+10
#
#     token smart contract  unnamed service      untraced
# 0           2.627863e+12     4.096867e+15  2.454987e+13
# 1           2.142902e+12     1.618505e+13  1.305360e+09
# 2           6.869175e+08     5.622850e+11  6.509343e+07
# 3           0.000000e+00     1.709459e+09  0.000000e+00
# 4           0.000000e+00     0.000000e+00  0.000000e+00
# 5           1.474370e+09     0.000000e+00  0.000000e+00
# 6           8.249259e+09     0.000000e+00  0.000000e+00
# 7           0.000000e+00     4.701567e+11  0.000000e+00
# 8           0.000000e+00     1.495200e+09  0.000000e+00
# 9           0.000000e+00     0.000000e+00  0.000000e+00
# 10          2.627864e+12     4.096867e+15  2.636925e+13
#
# [11 rows x 33 columns]
